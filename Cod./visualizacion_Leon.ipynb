# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import os
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
df=pd.read_csv('/workspaces/Entrega1/data/chocolate_bars_UTF8v5 - chocolate_bars_UTF8v5.csv')
df
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454          NaN           U.S.A.           2019            Tanzania
# 1     2458          NaN           U.S.A.           2019  Dominican Republic
# 2     2454          NaN           U.S.A.           2019          Madagascar
# 3     2542          NaN           U.S.A.           2021                Fiji
# 4     2546          NaN           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
# ...

# %%
df= df[df['rating'].notna()]
df.insert(17,'contador',1)
df.insert(18,'suma acum',df['contador'].cumsum())
df=df.sort_values('rating',ascending= True)
df
# Out:
#         id                     manufacturer company_location  year_reviewed  \
# 430    141                        Callebaut          Belgium           2007
# 590    252                  Claudio Corallo         Sao Tome           2008
# 1679   135              Neuhaus (Callebaut)          Belgium           2007
# 632     48               Cote d' Or (Kraft)          Belgium           2006
# 1587   887                       Middlebury           U.S.A.           2012
# ...    ...                              ...              ...            ...
# 2148   676                             Soma           Canada           2011
# 298     48                           Bonnat           France           2006
# 968    745                           Fresco           U.S.A.           2011
# 491   2688                       Castronovo           U.S.A.           2021
# 999   1375  Fresh Coast aka Just Good Choc_           U.S.A.           2014
#
# ...

# %%
df[df['rating']=='NaN']
# Out:
# Empty DataFrame
# Columns: [id, manufacturer, company_location, year_reviewed, bean_origin, bar_name, cocoa_percent, num_ingredients, Beans, Sugat, Sweetener, Cocoa_butter, Vanilla, Lecithin, Salt, review, rating, contador, suma acum]
# Index: []

# %%
cp=pd.DataFrame
cp=df.groupby('id')['cocoa_percent','rating'].head(2)
cp=cp.sort_values('cocoa_percent',ascending= True)
cp
# Out:
# /tmp/ipykernel_7744/1973823276.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cp=df.groupby('id')['cocoa_percent','rating'].head(2)
#       cocoa_percent  rating
# 578            42.0    2.75
# 1413           46.0    2.75
# 2029           53.0    2.00
# 451            55.0    3.00
# 1422           55.0    2.25
# ...             ...     ...
# 2457          100.0    2.25
# 1776          100.0    2.00
# 1106          100.0    2.00
# 164           100.0    1.75
# 1180          100.0    1.75
#
# [1252 rows x 2 columns]

# %%
x=cp['cocoa_percent']
y=cp['rating'] 
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(x,y,label='Rating')
ax.set_xlabel('cocoa_percent')
ax.set_ylabel('rating')
ax.set_title('porcentaje de cacao v/s puntaje')
ax.legend()

# %% [markdown]
# ## De la grafica podemos inferir que el porcentaje de cacao, no es necesariamente direcctamente proporcional, en el total de su rango, pero vale la pena estudiar a mayor detalle el rango 65%-75%

# %%
sugar=pd.DataFrame
sugar=df.groupby('id')['Sugat','rating','contador'].head(2)
sugar
# Out:
# /tmp/ipykernel_7744/809402425.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sugar=df.groupby('id')['Sugat','rating','contador'].head(2)
#       Sugat  rating  contador
# 430       0     1.0         1
# 590       0     1.0         1
# 1679      1     1.0         1
# 632       0     1.0         1
# 1587      0     1.5         1
# ...     ...     ...       ...
# 2168      1     4.0         1
# 1221      1     4.0         1
# 235       1     4.0         1
# 1840      1     4.0         1
# 301       1     4.0         1
#
# [1252 rows x 3 columns]

# %%
sweetener=pd.DataFrame
sweetener=df.groupby('id')['Sweetener','rating','contador'].head(2)
sweetener_df=sweetener[sweetener['Sweetener']==1]
sweetener_df
sweetener_df=sweetener_df.groupby('rating').count()
sweetener_df
# Out:
# /tmp/ipykernel_7744/4084800969.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sweetener=df.groupby('id')['Sweetener','rating','contador'].head(2)
#         Sweetener  contador
# rating
# 1.50            1         1
# 2.00            1         1
# 2.25            2         2
# 2.50            6         6
# 2.75           13        13
# 3.00           11        11
# 3.25            8         8
# 3.50            1         1

# %%
plt.figure()
# Figure -level
ax = sns.displot(data=sweetener_df, x='rating')
ax.set(xlabel='Endulzante', ylabel='Evaluacion', title='Evaluacion')

# %%
sugar_df=sugar[sugar['Sugat']==1]
sugar_df.insert(3,'suma acum',sugar_df['contador'].cumsum())
sugar_df
# Out:
#       Sugat  rating  contador  suma acum
# 1679      1     1.0         1          1
# 2383      1     1.5         1          2
# 2118      1     1.5         1          3
# 763       1     1.5         1          4
# 426       1     1.5         1          5
# ...     ...     ...       ...        ...
# 2168      1     4.0         1       1154
# 1221      1     4.0         1       1155
# 235       1     4.0         1       1156
# 1840      1     4.0         1       1157
# 301       1     4.0         1       1158
#
# [1158 rows x 4 columns]

# %%
Azucar=pd.DataFrame
Azucar=df.groupby('id')['Sugat','rating','contador'].head(2)
Azucar_df=Azucar[Azucar['Sugat']==1]
Azucar_df
Azucar_df=Azucar_df.groupby('rating').count()
Azucar_df
# Out:
# /tmp/ipykernel_7744/3806975706.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Azucar=df.groupby('id')['Sugat','rating','contador'].head(2)
#         Sugat  contador
# rating
# 1.00        1         1
# 1.50        4         4
# 1.75        1         1
# 2.00       26        26
# 2.25       12        12
# 2.50      138       138
# 2.75      265       265
# 3.00      316       316
# 3.25      208       208
# 3.50      148       148
# 3.75       32        32
# 4.00        7         7

# %%
plt.figure()
# Figure -level
ax = sns.displot(data=sweetener_df, x='rating')
ax.set(xlabel='Azucar', ylabel='Evaluacion', title='Evaluacion')

# %%
ing=pd.DataFrame
ing=df.groupby('id')['Sugat','rating','Cocoa_butter'].head(2)
ing.loc[ing['Cocoa_butter']==0,'Cocoa_butter']='Sin manteca de cacao'
ing.loc[ing['Cocoa_butter']==1,'Cocoa_butter']='con manteca de cacao'
ing
# Out:
# /tmp/ipykernel_7744/4212116583.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ing=df.groupby('id')['Sugat','rating','Cocoa_butter'].head(2)
#       Sugat  rating          Cocoa_butter
# 430       0     1.0  Sin manteca de cacao
# 590       0     1.0  Sin manteca de cacao
# 1679      1     1.0  con manteca de cacao
# 632       0     1.0  Sin manteca de cacao
# 1587      0     1.5  con manteca de cacao
# ...     ...     ...                   ...
# 2168      1     4.0  con manteca de cacao
# 1221      1     4.0  con manteca de cacao
# 235       1     4.0  con manteca de cacao
# 1840      1     4.0  con manteca de cacao
# 301       1     4.0  con manteca de cacao
#
# [1252 rows x 3 columns]

# %%
sns.displot(data=ing,x='rating',kind='hist',hue='Cocoa_butter')

# %% [markdown]
# ##La presencia de manteca de cacao logra aumentar la calidad del chocolate

# %%
ax = sns.catplot(data=ing, kind='violin', x='Sugat', y='rating', hue='Cocoa_butter', split=True)
ax.set(xlabel='Duración de ejercicio', ylabel='Frecuencia cardíaca', title='Categorización de la distribución de pulsaciones')

# %%
##La presencia de manteca de cacao logra aumentar la calidad del chocolate
